# %%
import pyarrow.parquet as pq
import pandas as pd
from clustergram import Clustergram
import sklearn
import cudf
import matplotlib.pyplot as plt
import pickle

# %%
df = cudf.read_parquet('/rapids/my_data/usa.bg.cc.parquet')

# %%
df
# Out:
#                GEOID  Male_Under_5_years  Male_5_to_9_years  \
# 0       020130001001           -3.955508          -6.000000
# 1       020130001002           -3.458307          -3.514030
# 2       020130001003           -4.357563          -4.583265
# 3       020160001001           -3.263576          -3.652820
# 4       020160002001           -3.900909          -4.014261
# ...              ...                 ...                ...
# 236770  560459511001           -3.134890          -3.359537
# 236771  560459511002           -4.940343          -3.891162
# 236772  560459513001           -2.661693          -2.393339
# 236773  560459513002           -4.680706          -3.266200
# 236774  560459513003           -5.164786          -2.246591
#
#         Male_10_to_14_years  Male_15_to_17_years  Male_20_years  \
# 0                 -6.000000            -5.763099      -4.455404
# 1                 -3.283414            -4.406719      -4.720121
# 2                 -3.553615            -4.015954      -6.000000
# 3                 -3.324600            -3.048942      -3.946961
# 4                 -4.108226            -4.455932      -5.474893
# ...                     ...                  ...            ...
# 236770            -3.209880            -4.105591      -6.000000
# 236771            -4.501116            -6.000000      -3.532359
# 236772            -6.000000            -3.173704      -6.000000
# 236773            -6.000000            -3.590076      -6.000000
# 236774            -6.000000            -4.553877      -6.000000
#
#         Male_21_years  Male_22_to_24_years  Male_25_to_29_years  \
# 0           -6.000000            -3.057724            -2.303734
# 1           -6.000000            -3.485803            -3.173878
# 2           -6.000000            -4.117753            -2.949777
# 3           -4.649719            -5.465948            -3.001272
# 4           -4.912130            -3.874401            -2.964944
# ...               ...                  ...                  ...
# 236770      -6.000000            -3.969702            -3.164269
# 236771      -6.000000            -4.697228            -4.287193
# 236772      -6.000000            -6.000000            -2.689457
# 236773      -6.000000            -3.226991            -3.189153
# 236774      -6.000000            -3.022911            -6.000000
#
#         Male_30_to_34_years  ...  \
# 0                 -2.705826  ...
# 1                 -3.736026  ...
# 2                 -3.355153  ...
# 3                 -2.770354  ...
# 4                 -3.120895  ...
# ...                     ...  ...
# 236770            -4.002041  ...
# 236771            -2.871452  ...
# 236772            -2.661693  ...
# 236773            -3.082945  ...
# 236774            -4.174387  ...
#
#         Tablet_or_other_portable_wireless_computer_with_no_other_type_of_computing_device  \
# 0                                               -3.423176
# 1                                               -3.964886
# 2                                               -6.000000
# 3                                               -4.590057
# 4                                               -6.000000
# ...                                                   ...
# 236770                                          -4.153661
# 236771                                          -6.000000
# 236772                                          -6.000000
# 236773                                          -6.000000
# 236774                                          -2.473582
#
#         No_Computer  Dial_up_with_no_other_type_of_Internet_subscription  \
# 0         -2.197225                                          -6.000000
# 1         -1.584120                                          -6.000000
# 2         -2.534720                                          -6.000000
# 3         -2.436897                                          -6.000000
# 4         -3.206803                                          -5.545177
# ...             ...                                                ...
# 236770    -2.018559                                          -6.000000
# 236771    -1.514128                                          -6.000000
# 236772    -2.224072                                          -6.000000
# 236773    -3.512540                                          -6.000000
# 236774    -4.069027                                          -6.000000
#
#         Cellular_data_plan_with_no_other_type_of_Internet_subscription  \
# 0                                               -3.263576
# 1                                               -3.708137
# 2                                               -3.946424
# 3                                               -1.986732
# 4                                               -1.751486
# ...                                                   ...
# 236770                                          -0.633800
# 236771                                          -2.997455
# 236772                                          -0.723179
# 236773                                          -1.345764
# 236774                                          -0.747214
#
#         Broadband_such_as_cable_fiber_optic_or_DSL_with_no_other_type_of_Internet_subscription  \
# 0                                               -3.001272
# 1                                               -2.519998
# 2                                               -2.765060
# 3                                               -2.746202
# 4                                               -3.504556
# ...                                                   ...
# 236770                                          -2.264897
# 236771                                          -1.386294
# 236772                                          -2.179642
# 236773                                          -1.417966
# 236774                                          -4.360973
#
#         Satellite_Internet_service  Internet_access_without_a_subscription  \
# 0                        -2.386467                               -3.610918
# 1                        -2.559235                               -3.252587
# 2                        -1.291259                               -2.949439
# 3                        -2.308125                               -3.311585
# 4                        -1.691018                               -3.206803
# ...                            ...                                     ...
# 236770                   -2.613117                               -4.338597
# 236771                   -1.995539                               -2.961831
# 236772                   -2.654095                               -1.787119
# 236773                   -3.164068                               -1.369487
# 236774                   -1.274503                               -6.000000
#
#         No_Internet_access  Under_18_With_a_broadband_Internet_subscription  \
# 0                 0.748939                                        -2.348726
# 1                -0.522189                                        -1.785746
# 2                -1.079744                                        -2.039596
# 3                -1.318576                                        -1.203973
# 4                -2.005018                                        -1.781771
# ...                    ...                                              ...
# 236770           -1.548813                                        -1.176574
# 236771           -1.427794                                        -2.514836
# 236772           -1.755058                                        -1.023043
# 236773           -3.214868                                        -1.457516
# 236774           -3.180244                                        -1.340752
#
#         Under_18_Without_an_Internet_subscription
# 0                                       -2.926739
# 1                                       -2.477098
# 2                                       -2.854082
# 3                                       -2.877949
# 4                                       -3.900625
# ...                                           ...
# 236770                                  -5.370056
# 236771                                  -3.665963
# 236772                                  -6.000000
# 236773                                  -6.000000
# 236774                                  -6.000000
#
# [236775 rows x 191 columns]

# %%
df = df.set_index('GEOID')

# %%
cgram = Clustergram(range(1, 8), backend='cuML',n_init=10)

# %%
cgram.fit(df)

# %%
cgram = Clustergram(range(1, 15), backend='sklearn',n_init=1000)

# %%
df2= df.to_pandas()

# %%
cgram.fit(df2)
# Out:
# K=1 skipped. Mean computed from data directly.

# %%
cgram.plot(figsize=(12, 8))
plt.savefig('../clustergram.pdf')

# %%
with open('../data/clustergram.pickle','wb') as f:
    pickle.dump(cgram, f)
